# %%
pip install -U vectorbt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 2.9 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: vectorbt
#     Found existing installation: vectorbt 0.25.4
#     Uninstalling vectorbt-0.25.4:
#       Successfully uninstalled vectorbt-0.25.4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from datetime import datetime

import vectorbt as vbt

# Prepare data
start = '2019-01-01 UTC'  # crypto is in UTC
end = '2022-01-01 UTC'
btc_price = vbt.YFData.download('BTC-USD', start=start, end=end).get('Close')

btc_price
# Out:
# Date
# 2019-01-01 00:00:00+00:00     3843.520020
# 2019-01-02 00:00:00+00:00     3943.409424
# 2019-01-03 00:00:00+00:00     3836.741211
# 2019-01-04 00:00:00+00:00     3857.717529
# 2019-01-05 00:00:00+00:00     3845.194580
#                                  ...
# 2021-12-27 00:00:00+00:00    50640.417969
# 2021-12-28 00:00:00+00:00    47588.855469
# 2021-12-29 00:00:00+00:00    46444.710938
# 2021-12-30 00:00:00+00:00    47178.125000
# 2021-12-31 00:00:00+00:00    46306.445312
# Freq: D, Name: Close, Length: 1096, dtype: float64

# %%
import numpy as np
import pandas as pd
data = pd.read_csv("/Users/frank/vectorbt-research/data_base/BINANCE/SPOT/1m/ETHUSDT_SPOT_1m.csv")
data
# Out:
#                     datetime     open     high      low    close    volume
# 0        2017-08-17 12:00:00   301.13   301.13   301.13   301.13   0.42643
# 1        2017-08-17 12:01:00   301.13   301.13   301.13   301.13   2.75787
# 2        2017-08-17 12:02:00   300.00   300.00   300.00   300.00   0.09930
# 3        2017-08-17 12:03:00   300.00   300.00   300.00   300.00   0.31389
# 4        2017-08-17 12:04:00   301.13   301.13   301.13   301.13   0.23202
# ...                      ...      ...      ...      ...      ...       ...
# 3133517  2023-08-08 13:09:00  1834.31  1834.60  1834.30  1834.60  52.25790
# 3133518  2023-08-08 13:10:00  1834.59  1834.62  1834.59  1834.61  45.03360
# 3133519  2023-08-08 13:11:00  1834.61  1834.66  1834.61  1834.66  96.18660
# 3133520  2023-08-08 13:12:00  1834.65  1834.83  1834.65  1834.83  24.98490
# 3133521  2023-08-08 13:13:00  1834.82  1835.00  1834.60  1834.99  61.17490
#
# [3133522 rows x 6 columns]

# %% [markdown]
# 定義進出場邏輯

# %%
fast_ma = vbt.MA.run(btc_price, 10, short_name='fast') 
slow_ma = vbt.MA.run(btc_price, 20, short_name='slow')

#進場
entries = fast_ma.ma_crossed_above(slow_ma)
entries
#出場
exits = fast_ma.ma_crossed_below(slow_ma)
exits

pf = vbt.Portfolio.from_signals(btc_price, entries, exits)
pf.stats()
# Out:
# Start                          2019-01-01 00:00:00+00:00
# End                            2021-12-31 00:00:00+00:00
# Period                                1096 days 00:00:00
# Start Value                                        100.0
# End Value                                     849.869754
# Total Return [%]                              749.869754
# Benchmark Return [%]                         1104.792614
# Max Gross Exposure [%]                             100.0
# Total Fees Paid                                      0.0
# Max Drawdown [%]                               53.132957
# Max Drawdown Duration                  314 days 00:00:00
# Total Trades                                          27
# Total Closed Trades                                   26
# Total Open Trades                                      1
# Open Trade PnL                                -82.645585
# Win Rate [%]                                   42.307692
# ...

# %%
fig = pf.plot(subplots=['cum_returns', 'orders', 'trade_pnl'])
fig.show()

# %%
pf.positions.records_readable
# Out:
#     Position Id  Column      Size           Entry Timestamp  Avg Entry Price  \
# 0             0       0  0.027409 2019-02-11 00:00:00+00:00      3648.430664
# 1             1       0  0.027336 2019-03-13 00:00:00+00:00      3906.717285
# 2             2       0  0.023329 2019-06-17 00:00:00+00:00      9320.352539
# 3             3       0  0.021961 2019-07-15 00:00:00+00:00     10895.089844
# 4             4       0  0.018033 2019-08-05 00:00:00+00:00     11805.653320
# 5             5       0  0.017868 2019-09-08 00:00:00+00:00     10441.276367
# 6             6       0  0.021904 2019-10-14 00:00:00+00:00      8374.686523
# 7             7       0  0.018904 2019-10-28 00:00:00+00:00      9256.148438
# 8             8       0  0.022878 2019-12-10 00:00:00+00:00      7278.119629
# 9             9       0  0.022731 2019-12-27 00:00:00+00:00      7290.088379
# 10           10       0  0.036140 2020-03-28 00:00:00+00:00      6242.193848
# ...
